# %% [markdown]
# # KNN com o conjunto de dados Iris
#
# Sequência básica para carregar os dados, separar treino e teste, treinar, prever e avaliar um classificador KNN.

# %% [markdown]
# ## 1. Importar as bibliotecas

# %%
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %% [markdown]
# ## 2. Carregar os dados

# %%
df = pd.read_csv('clientes_knn.csv')
target_names = sorted(df['segmento'].unique())

X = df.drop(columns=['id_cliente', 'segmento']).values
y = df['segmento'].values

# %% [markdown]
# ## 3. Separar os dados de treino e teste

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(
    X, y, test_size=0.30, random_state=42, stratify=y
)

# %% [markdown]
# ## 4. Criar o pipeline
#
# O `StandardScaler` é ajustado somente com os dados de treino. Depois, o KNN utiliza os cinco vizinhos mais próximos.

# %%
modelo = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=5))

# %% [markdown]
# ## 5. Treinar o modelo

# %%
modelo.fit(X_treino, y_treino)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsclassifier', KNeighborsClassifier())])

# %% [markdown]
# ## 6. Fazer as previsões

# %%
y_previsto = modelo.predict(X_teste)

# %% [markdown]
# ## 7. Avaliar o modelo

# %%
acuracia = accuracy_score(y_teste, y_previsto)
matriz_confusao = confusion_matrix(y_teste, y_previsto, labels=target_names)
relatorio = classification_report(
    y_teste, y_previsto, target_names=target_names, digits=3
)

# %%
print(f"Acurácia Global: {acuracia:.4f}")
print("\nMatriz de confusão:")
print(matriz_confusao)
print("\nRelatório de classificação:")
print(relatorio)
# Out:
# Acurácia Global: 1.0000
#
# Matriz de confusão:
# [[18  0  0]
#  [ 0 18  0]
#  [ 0  0 18]]
#
# Relatório de classificação:
#               precision    recall  f1-score   support
#
#         alto      1.000     1.000     1.000        18
#        baixo      1.000     1.000     1.000        18
#        medio      1.000     1.000     1.000        18
#
#     accuracy                          1.000        54
#    macro avg      1.000     1.000     1.000        54
# weighted avg      1.000     1.000     1.000        54

# %% [markdown]
# ## 8. Classificar uma nova flor
#
# Informe as medidas, em centímetros, na ordem: comprimento da sépala, largura da sépala, comprimento da pétala e largura da pétala.

# %%
#comprimento da sépala, largura da sépala, comprimento da pétala, largura da pétala
novo_cliente = [[40, 7200, 6, 230, 7, 24]] 
classe_prevista = modelo.predict(novo_cliente)[0]
print("\n--- Predição para Novo Cliente ---")
print(f"Dados informados: {novo_cliente[0]}")
print("Segmento previsto para o cliente:", classe_prevista)
# Out:
# --- Predição para Novo Cliente ---
# Dados informados: [40, 7200, 6, 230, 7, 24]
# Segmento previsto para o cliente: medio
