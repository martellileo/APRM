# %% [markdown]
# # Atividade: KNN na base de clientes tratada
#
# Complete as células com código Python. O objetivo é prever o rótulo **ativo** a partir da idade e da renda mensal do cliente.

# %%
# Importe o pandas, o matplotlib e os recursos necessários do scikit-learn para divisão dos dados, normalização, KNN e avaliação.

# %%
# Localize a pasta da base e carregue o arquivo clientes_tratados.csv em um DataFrame.

# %%
# Exiba as primeiras linhas, as dimensões, os tipos de dados e a quantidade de clientes de cada rótulo da coluna ativo.

# %%
# Crie X com as colunas idade e renda_mensal. Crie y com o rótulo ativo.

# %%
# Separe X e y em treino e teste. Use 30% para teste, random_state igual a 42 e mantenha a proporção dos rótulos.

# %%
# Para k igual a 1, 3 e 5, crie um Pipeline com StandardScaler e KNeighborsClassifier, treine e registre a acurácia no teste.

# %%
# Organize os resultados em um DataFrame, exiba-os e faça um gráfico da acurácia por valor de k.

# %%
# Descubra o melhor k. Em caso de empate, mantenha o menor valor de k.

# %%
# Crie e treine o Pipeline final, usando StandardScaler e o melhor valor de k.

# %%
# Faça previsões para X_test e avalie o modelo com acurácia, matriz de confusão e relatório de classificação.

# %%
# Crie um novo cliente com idade 30 e renda_mensal 4800.00, respeitando os nomes e a ordem das colunas de X.

# %%
# Preveja o rótulo ativo do novo cliente e exiba a probabilidade calculada para cada classe.

# %% [markdown]
# ## Reflexão
#
# Explique por que a normalização é importante no KNN e por que a acurácia obtida com uma base tão pequena deve ser interpretada com cautela.
