# %%
# Importe a biblioteca pandas.

# %%
# Carregue o arquivo frutas_knn.csv em um DataFrame.

# %%
# Exiba as primeiras e as últimas linhas da base de frutas.

# %%
# Descubra a quantidade de linhas e colunas da base.

# %%
# Consulte os nomes das colunas e os tipos de dados de cada uma.

# %%
# Verifique se existem valores ausentes em cada coluna.

# %%
# Gere estatísticas descritivas para as colunas numéricas.

# %%
# Conte quantas frutas existem em cada classe.

# %%
# Compare as médias dos atributos numéricos agrupando as frutas por classe.
